# %% [markdown]
# # Reserve and configure FABRIC resources for reproducing "Revisiting TCP Congestion Control Throughput Models & Fairness Properties at Scale"

# %% [markdown]
# ## Set up your FABRIC environment
#
# This assumes that you have already configured your FABRIC account and your Jupyter environment as described in [Hello, FABRIC](https://teaching-on-testbeds.github.io/blog/hello-fabric).

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
fablib = fablib_manager() 
fablib.show_config()
# Out:
# <style type="text/css">
# #T_7f4b9 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_7f4b9 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7f4b9 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_7f4b9_row0_col0, #T_7f4b9_row0_col1, #T_7f4b9_row1_col0, #T_7f4b9_row1_col1, #T_7f4b9_row2_col0, #T_7f4b9_row2_col1, #T_7f4b9_row3_col0, #T_7f4b9_row3_col1, #T_7f4b9_row4_col0, #T_7f4b9_row4_col1, #T_7f4b9_row5_col0, #T_7f4b9_row5_col1, #T_7f4b9_row6_col0, #T_7f4b9_row6_col1, #T_7f4b9_row7_col0, #T_7f4b9_row7_col1, #T_7f4b9_row8_col0, #T_7f4b9_row8_col1, #T_7f4b9_row9_col0, #T_7f4b9_row9_col1, #T_7f4b9_row10_col0, #T_7f4b9_row10_col1, #T_7f4b9_row11_col0, #T_7f4b9_row11_col1, #T_7f4b9_row12_col0, #T_7f4b9_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_7f4b9">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f4b9_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_7f4b9_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_7f4b9_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_7f4b9_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_7f4b9_row3_col1" class="data row3 col1" >073ee843-2310-45bd-a01f-a15d808827dc</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_7f4b9_row4_col1" class="data row4 col1" >ffund_0041777137</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_7f4b9_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_7f4b9_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_7f4b9_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_7f4b9_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_7f4b9_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_7f4b9_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_7f4b9_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_7f4b9_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7f4b9 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_7f4b9 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7f4b9 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_7f4b9_row0_col0, #T_7f4b9_row0_col1, #T_7f4b9_row1_col0, #T_7f4b9_row1_col1, #T_7f4b9_row2_col0, #T_7f4b9_row2_col1, #T_7f4b9_row3_col0, #T_7f4b9_row3_col1, #T_7f4b9_row4_col0, #T_7f4b9_row4_col1, #T_7f4b9_row5_col0, #T_7f4b9_row5_col1, #T_7f4b9_row6_col0, #T_7f4b9_row6_col1, #T_7f4b9_row7_col0, #T_7f4b9_row7_col1, #T_7f4b9_row8_col0, #T_7f4b9_row8_col1, #T_7f4b9_row9_col0, #T_7f4b9_row9_col1, #T_7f4b9_row10_col0, #T_7f4b9_row10_col1, #T_7f4b9_row11_col0, #T_7f4b9_row11_col1, #T_7f4b9_row12_col0, #T_7f4b9_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_7f4b9">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f4b9_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_7f4b9_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_7f4b9_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_7f4b9_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_7f4b9_row3_col1" class="data row3 col1" >073ee843-2310-45bd-a01f-a15d808827dc</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_7f4b9_row4_col1" class="data row4 col1" >ffund_0041777137</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_7f4b9_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_7f4b9_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_7f4b9_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_7f4b9_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_7f4b9_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_7f4b9_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_7f4b9_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_7f4b9_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_7f4b9_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !chmod 600 {fablib.get_bastion_key_filename()}
# !chmod 600 {fablib.get_default_slice_private_key_file()}

# %% [markdown]
# ## Create and submit a slice

# %%
n_endpoints = 10
slice_name="bottleneck-" + str(n_endpoints) + '-test'
slice = fablib.new_slice(name=slice_name)

# %% [markdown]
# This cell will try to identify a site that has sufficient resources for your experiment. But, you should still check in the [FABRIC Portal](https://portal.fabric-testbed.net/resources/all) to make sure it is not in maintenance or out of service - if so, you should run the cell again until you get a site that is ready to use.

# %%
exp_requires = {'core': 2*n_endpoints*4+32, 'nic': 2*n_endpoints*1, 'connectx5': 1}
while True:
    site_name = fablib.get_random_site()
    if ( (fablib.resources.get_core_available(site_name) > 1.2*exp_requires['core']) and
        (fablib.resources.get_component_available(site_name, 'SharedNIC-ConnectX-6') > 1.2**exp_requires['nic']) and
        (fablib.resources.get_component_available(site_name, 'SmartNIC-ConnectX-5') > 1.2*exp_requires['connectx5'])   ):
        break

fablib.show_site(site_name)
# Out:
# <style type="text/css">
# #T_3e23f tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_3e23f tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3e23f caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_3e23f_row0_col0, #T_3e23f_row0_col1, #T_3e23f_row1_col0, #T_3e23f_row1_col1, #T_3e23f_row2_col0, #T_3e23f_row2_col1, #T_3e23f_row3_col0, #T_3e23f_row3_col1, #T_3e23f_row4_col0, #T_3e23f_row4_col1, #T_3e23f_row5_col0, #T_3e23f_row5_col1, #T_3e23f_row6_col0, #T_3e23f_row6_col1, #T_3e23f_row7_col0, #T_3e23f_row7_col1, #T_3e23f_row8_col0, #T_3e23f_row8_col1, #T_3e23f_row9_col0, #T_3e23f_row9_col1, #T_3e23f_row10_col0, #T_3e23f_row10_col1, #T_3e23f_row11_col0, #T_3e23f_row11_col1, #T_3e23f_row12_col0, #T_3e23f_row12_col1, #T_3e23f_row13_col0, #T_3e23f_row13_col1, #T_3e23f_row14_col0, #T_3e23f_row14_col1, #T_3e23f_row15_col0, #T_3e23f_row15_col1, #T_3e23f_row16_col0, #T_3e23f_row16_col1, #T_3e23f_row17_col0, #T_3e23f_row17_col1, #T_3e23f_row18_col0, #T_3e23f_row18_col1, #T_3e23f_row19_col0, #T_3e23f_row19_col1, #T_3e23f_row20_col0, #T_3e23f_row20_col1, #T_3e23f_row21_col0, #T_3e23f_row21_col1, #T_3e23f_row22_col0, #T_3e23f_row22_col1, #T_3e23f_row23_col0, #T_3e23f_row23_col1, #T_3e23f_row24_col0, #T_3e23f_row24_col1, #T_3e23f_row25_col0, #T_3e23f_row25_col1, #T_3e23f_row26_col0, #T_3e23f_row26_col1, #T_3e23f_row27_col0, #T_3e23f_row27_col1, #T_3e23f_row28_col0, #T_3e23f_row28_col1, #T_3e23f_row29_col0, #T_3e23f_row29_col1, #T_3e23f_row30_col0, #T_3e23f_row30_col1, #T_3e23f_row31_col0, #T_3e23f_row31_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_3e23f">
#   <caption>Site</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3e23f_row0_col0" class="data row0 col0" >Name</td>
#       <td id="T_3e23f_row0_col1" class="data row0 col1" >DALL</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row1_col0" class="data row1 col0" >Address</td>
#       <td id="T_3e23f_row1_col1" class="data row1 col1" >1950 N Stemmons Fwy,Dallas, TX 75207</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row2_col0" class="data row2 col0" >Location</td>
#       <td id="T_3e23f_row2_col1" class="data row2 col1" >(32.8002714, -96.8198113)</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row3_col0" class="data row3 col0" >Hosts</td>
#       <td id="T_3e23f_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row4_col0" class="data row4 col0" >CPUs</td>
#       <td id="T_3e23f_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row5_col0" class="data row5 col0" >Cores Available</td>
#       <td id="T_3e23f_row5_col1" class="data row5 col1" >152</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row6_col0" class="data row6 col0" >Cores Capacity</td>
#       <td id="T_3e23f_row6_col1" class="data row6 col1" >192</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row7_col0" class="data row7 col0" >Cores Allocated</td>
#       <td id="T_3e23f_row7_col1" class="data row7 col1" >40</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row8_col0" class="data row8 col0" >RAM Available</td>
#       <td id="T_3e23f_row8_col1" class="data row8 col1" >1392</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row9_col0" class="data row9 col0" >RAM Capacity</td>
#       <td id="T_3e23f_row9_col1" class="data row9 col1" >1536</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row10_col0" class="data row10 col0" >RAM Allocated</td>
#       <td id="T_3e23f_row10_col1" class="data row10 col1" >144</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row11_col0" class="data row11 col0" >Disk Available</td>
#       <td id="T_3e23f_row11_col1" class="data row11 col1" >60050</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row12_col0" class="data row12 col0" >Disk Capacity</td>
#       <td id="T_3e23f_row12_col1" class="data row12 col1" >60600</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row13_col0" class="data row13 col0" >Disk Allocated</td>
#       <td id="T_3e23f_row13_col1" class="data row13 col1" >550</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row14_col0" class="data row14 col0" >Basic NIC Available</td>
#       <td id="T_3e23f_row14_col1" class="data row14 col1" >379</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row15_col0" class="data row15 col0" >Basic NIC Capacity</td>
#       <td id="T_3e23f_row15_col1" class="data row15 col1" >381</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row16_col0" class="data row16 col0" >Basic NIC Allocated</td>
#       <td id="T_3e23f_row16_col1" class="data row16 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row17_col0" class="data row17 col0" >ConnectX-6 Available</td>
#       <td id="T_3e23f_row17_col1" class="data row17 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row18_col0" class="data row18 col0" >ConnectX-6 Capacity</td>
#       <td id="T_3e23f_row18_col1" class="data row18 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row19_col0" class="data row19 col0" >ConnectX-6 Allocated</td>
#       <td id="T_3e23f_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row20_col0" class="data row20 col0" >ConnectX-5 Available</td>
#       <td id="T_3e23f_row20_col1" class="data row20 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row21_col0" class="data row21 col0" >ConnectX-5 Capacity</td>
#       <td id="T_3e23f_row21_col1" class="data row21 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row22_col0" class="data row22 col0" >ConnectX-5 Allocated</td>
#       <td id="T_3e23f_row22_col1" class="data row22 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row23_col0" class="data row23 col0" >NVMe Available</td>
#       <td id="T_3e23f_row23_col1" class="data row23 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row24_col0" class="data row24 col0" >NVMe Capacity</td>
#       <td id="T_3e23f_row24_col1" class="data row24 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row25_col0" class="data row25 col0" >NVMe Allocated</td>
#       <td id="T_3e23f_row25_col1" class="data row25 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row26_col0" class="data row26 col0" >Tesla T4 Available</td>
#       <td id="T_3e23f_row26_col1" class="data row26 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row27_col0" class="data row27 col0" >Tesla T4 Capacity</td>
#       <td id="T_3e23f_row27_col1" class="data row27 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row28_col0" class="data row28 col0" >Tesla T4 Allocated</td>
#       <td id="T_3e23f_row28_col1" class="data row28 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row29_col0" class="data row29 col0" >RTX6000 Available</td>
#       <td id="T_3e23f_row29_col1" class="data row29 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row30_col0" class="data row30 col0" >RTX6000 Capacity</td>
#       <td id="T_3e23f_row30_col1" class="data row30 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_3e23f_row31_col0" class="data row31 col0" >RTX6000 Allocated</td>
#       <td id="T_3e23f_row31_col1" class="data row31 col1" >0</td>
#     </tr>
#   </tbody>
# </table>
# '<pandas.io.formats.style.Styler object at 0x7f6b28354970>'

# %%
# this cell sets up the hosts
slice.add_node(name='router', site=site_name, cores=32, ram=256, disk=25, image='default_ubuntu_22')

sender_names = ["sender-"+str(i) for i in range(n_endpoints)]
for n in sender_names:
    slice.add_node(name=n, site=site_name, cores=4, ram=32, disk=10, image='default_ubuntu_18')
    
receive_names = ["receiver-"+str(i) for i in range(n_endpoints)]
for n in receive_names:
    slice.add_node(name=n, site=site_name, cores=4, ram=32, disk=10, image='default_ubuntu_18')

# %%
# this cell sets up the network links
nets = [
    {"name": "link-sender",    "nodes": sender_names,  "idx": 0},
    {"name": "link-receiver",  "nodes": receive_names, "idx": 1}
]

router_iface = slice.get_node('router').add_component(model="NIC_ConnectX_5", name='link').get_interfaces()

for n in nets:
    ifaces = [slice.get_node(node).add_component(model="NIC_Basic", name=n["name"]).get_interfaces()[0] for node in n['nodes'] ] + [router_iface[n["idx"]]]
    slice.add_l2network(name=n["name"], type='L2Bridge', interfaces=ifaces)

# %% [markdown]
# When everything is ready, submit the slice and wait for it to get to "StableOK" state.  You can also see the state of your slice on the browser-based interface at https://portal.fabric-testbed.net/experiments#slices.
#
# In case of an error, you can modify the slice name in the first cell of the "Create and submit a slice" section, to try again with a new slice (different name). Then, return to this cell and click Run > Run All Above Selected Cell. Finally, re-run the `slice.submit()` cell.

# %%
slice.submit()
# Out:
# Retry: 2, Time: 1318 sec
# <style type="text/css">
# #T_53cc7 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_53cc7 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_53cc7 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_53cc7_row0_col0, #T_53cc7_row0_col1, #T_53cc7_row1_col0, #T_53cc7_row1_col1, #T_53cc7_row2_col0, #T_53cc7_row2_col1, #T_53cc7_row3_col0, #T_53cc7_row3_col1, #T_53cc7_row4_col0, #T_53cc7_row4_col1, #T_53cc7_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_53cc7_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_53cc7">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_53cc7_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_53cc7_row0_col1" class="data row0 col1" >1ebcf68b-84a8-4994-b09b-ca3d8320e0f7</td>
#     </tr>
#     <tr>
#       <td id="T_53cc7_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_53cc7_row1_col1" class="data row1 col1" >bottleneck-10-test</td>
#     </tr>
#     <tr>
#       <td id="T_53cc7_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_53cc7_row2_col1" class="data row2 col1" >2023-05-12 15:41:59 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_53cc7_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_53cc7_row3_col1" class="data row3 col1" >2023-05-11 15:42:01 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_53cc7_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_53cc7_row4_col1" class="data row4 col1" >073ee843-2310-45bd-a01f-a15d808827dc</td>
#     </tr>
#     <tr>
#       <td id="T_53cc7_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_53cc7_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1d1e4 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_1d1e4 th {
#   text-align: left;
# }
# #T_1d1e4 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1d1e4 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_1d1e4 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1d1e4_row0_col0, #T_1d1e4_row0_col1, #T_1d1e4_row0_col2, #T_1d1e4_row0_col3, #T_1d1e4_row0_col4, #T_1d1e4_row0_col5, #T_1d1e4_row0_col6, #T_1d1e4_row0_col7, #T_1d1e4_row0_col8, #T_1d1e4_row0_col9, #T_1d1e4_row0_col10, #T_1d1e4_row0_col13, #T_1d1e4_row0_col14, #T_1d1e4_row0_col15, #T_1d1e4_row1_col0, #T_1d1e4_row1_col1, #T_1d1e4_row1_col2, #T_1d1e4_row1_col3, #T_1d1e4_row1_col4, #T_1d1e4_row1_col5, #T_1d1e4_row1_col6, #T_1d1e4_row1_col7, #T_1d1e4_row1_col8, #T_1d1e4_row1_col9, #T_1d1e4_row1_col10, #T_1d1e4_row1_col13, #T_1d1e4_row1_col14, #T_1d1e4_row1_col15, #T_1d1e4_row2_col0, #T_1d1e4_row2_col1, #T_1d1e4_row2_col2, #T_1d1e4_row2_col3, #T_1d1e4_row2_col4, #T_1d1e4_row2_col5, #T_1d1e4_row2_col6, #T_1d1e4_row2_col7, #T_1d1e4_row2_col8, #T_1d1e4_row2_col9, #T_1d1e4_row2_col10, #T_1d1e4_row2_col13, #T_1d1e4_row2_col14, #T_1d1e4_row2_col15, #T_1d1e4_row3_col0, #T_1d1e4_row3_col1, #T_1d1e4_row3_col2, #T_1d1e4_row3_col3, #T_1d1e4_row3_col4, #T_1d1e4_row3_col5, #T_1d1e4_row3_col6, #T_1d1e4_row3_col7, #T_1d1e4_row3_col8, #T_1d1e4_row3_col9, #T_1d1e4_row3_col10, #T_1d1e4_row3_col13, #T_1d1e4_row3_col14, #T_1d1e4_row3_col15, #T_1d1e4_row4_col0, #T_1d1e4_row4_col1, #T_1d1e4_row4_col2, #T_1d1e4_row4_col3, #T_1d1e4_row4_col4, #T_1d1e4_row4_col5, #T_1d1e4_row4_col6, #T_1d1e4_row4_col7, #T_1d1e4_row4_col8, #T_1d1e4_row4_col9, #T_1d1e4_row4_col10, #T_1d1e4_row4_col13, #T_1d1e4_row4_col14, #T_1d1e4_row4_col15, #T_1d1e4_row5_col0, #T_1d1e4_row5_col1, #T_1d1e4_row5_col2, #T_1d1e4_row5_col3, #T_1d1e4_row5_col4, #T_1d1e4_row5_col5, #T_1d1e4_row5_col6, #T_1d1e4_row5_col7, #T_1d1e4_row5_col8, #T_1d1e4_row5_col9, #T_1d1e4_row5_col10, #T_1d1e4_row5_col13, #T_1d1e4_row5_col14, #T_1d1e4_row5_col15, #T_1d1e4_row6_col0, #T_1d1e4_row6_col1, #T_1d1e4_row6_col2, #T_1d1e4_row6_col3, #T_1d1e4_row6_col4, #T_1d1e4_row6_col5, #T_1d1e4_row6_col6, #T_1d1e4_row6_col7, #T_1d1e4_row6_col8, #T_1d1e4_row6_col9, #T_1d1e4_row6_col10, #T_1d1e4_row6_col13, #T_1d1e4_row6_col14, #T_1d1e4_row6_col15, #T_1d1e4_row7_col0, #T_1d1e4_row7_col1, #T_1d1e4_row7_col2, #T_1d1e4_row7_col3, #T_1d1e4_row7_col4, #T_1d1e4_row7_col5, #T_1d1e4_row7_col6, #T_1d1e4_row7_col7, #T_1d1e4_row7_col8, #T_1d1e4_row7_col9, #T_1d1e4_row7_col10, #T_1d1e4_row7_col13, #T_1d1e4_row7_col14, #T_1d1e4_row7_col15, #T_1d1e4_row8_col0, #T_1d1e4_row8_col1, #T_1d1e4_row8_col2, #T_1d1e4_row8_col3, #T_1d1e4_row8_col4, #T_1d1e4_row8_col5, #T_1d1e4_row8_col6, #T_1d1e4_row8_col7, #T_1d1e4_row8_col8, #T_1d1e4_row8_col9, #T_1d1e4_row8_col10, #T_1d1e4_row8_col13, #T_1d1e4_row8_col14, #T_1d1e4_row8_col15, #T_1d1e4_row9_col0, #T_1d1e4_row9_col1, #T_1d1e4_row9_col2, #T_1d1e4_row9_col3, #T_1d1e4_row9_col4, #T_1d1e4_row9_col5, #T_1d1e4_row9_col6, #T_1d1e4_row9_col7, #T_1d1e4_row9_col8, #T_1d1e4_row9_col9, #T_1d1e4_row9_col10, #T_1d1e4_row9_col13, #T_1d1e4_row9_col14, #T_1d1e4_row9_col15, #T_1d1e4_row10_col0, #T_1d1e4_row10_col1, #T_1d1e4_row10_col2, #T_1d1e4_row10_col3, #T_1d1e4_row10_col4, #T_1d1e4_row10_col5, #T_1d1e4_row10_col6, #T_1d1e4_row10_col7, #T_1d1e4_row10_col8, #T_1d1e4_row10_col9, #T_1d1e4_row10_col10, #T_1d1e4_row10_col13, #T_1d1e4_row10_col14, #T_1d1e4_row10_col15, #T_1d1e4_row11_col0, #T_1d1e4_row11_col1, #T_1d1e4_row11_col2, #T_1d1e4_row11_col3, #T_1d1e4_row11_col4, #T_1d1e4_row11_col5, #T_1d1e4_row11_col6, #T_1d1e4_row11_col7, #T_1d1e4_row11_col8, #T_1d1e4_row11_col9, #T_1d1e4_row11_col10, #T_1d1e4_row11_col13, #T_1d1e4_row11_col14, #T_1d1e4_row11_col15, #T_1d1e4_row12_col0, #T_1d1e4_row12_col1, #T_1d1e4_row12_col2, #T_1d1e4_row12_col3, #T_1d1e4_row12_col4, #T_1d1e4_row12_col5, #T_1d1e4_row12_col6, #T_1d1e4_row12_col7, #T_1d1e4_row12_col8, #T_1d1e4_row12_col9, #T_1d1e4_row12_col10, #T_1d1e4_row12_col13, #T_1d1e4_row12_col14, #T_1d1e4_row12_col15, #T_1d1e4_row13_col0, #T_1d1e4_row13_col1, #T_1d1e4_row13_col2, #T_1d1e4_row13_col3, #T_1d1e4_row13_col4, #T_1d1e4_row13_col5, #T_1d1e4_row13_col6, #T_1d1e4_row13_col7, #T_1d1e4_row13_col8, #T_1d1e4_row13_col9, #T_1d1e4_row13_col10, #T_1d1e4_row13_col13, #T_1d1e4_row ...
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_1d1e4_row0_col11, #T_1d1e4_row1_col11, #T_1d1e4_row2_col11, #T_1d1e4_row3_col11, #T_1d1e4_row4_col11, #T_1d1e4_row5_col11, #T_1d1e4_row6_col11, #T_1d1e4_row7_col11, #T_1d1e4_row8_col11, #T_1d1e4_row9_col11, #T_1d1e4_row10_col11, #T_1d1e4_row11_col11, #T_1d1e4_row12_col11, #T_1d1e4_row13_col11, #T_1d1e4_row14_col11, #T_1d1e4_row15_col11, #T_1d1e4_row16_col11, #T_1d1e4_row17_col11, #T_1d1e4_row18_col11, #T_1d1e4_row19_col11, #T_1d1e4_row20_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_1d1e4_row0_col12, #T_1d1e4_row1_col12, #T_1d1e4_row2_col12, #T_1d1e4_row3_col12, #T_1d1e4_row4_col12, #T_1d1e4_row5_col12, #T_1d1e4_row6_col12, #T_1d1e4_row7_col12, #T_1d1e4_row8_col12, #T_1d1e4_row9_col12, #T_1d1e4_row10_col12, #T_1d1e4_row11_col12, #T_1d1e4_row12_col12, #T_1d1e4_row13_col12, #T_1d1e4_row14_col12, #T_1d1e4_row15_col12, #T_1d1e4_row16_col12, #T_1d1e4_row17_col12, #T_1d1e4_row18_col12, #T_1d1e4_row19_col12, #T_1d1e4_row20_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_1d1e4">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_1d1e4_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_1d1e4_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_1d1e4_level0_col2" class="col_heading level0
# <style type="text/css">
# #T_b3195 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_b3195 th {
#   text-align: left;
# }
# #T_b3195 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b3195 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b3195 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b3195_row0_col0, #T_b3195_row0_col1, #T_b3195_row0_col2, #T_b3195_row0_col3, #T_b3195_row0_col4, #T_b3195_row0_col5, #T_b3195_row0_col6, #T_b3195_row1_col0, #T_b3195_row1_col1, #T_b3195_row1_col2, #T_b3195_row1_col3, #T_b3195_row1_col4, #T_b3195_row1_col5, #T_b3195_row1_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_b3195_row0_col7, #T_b3195_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_b3195_row0_col8, #T_b3195_row1_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_b3195">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_b3195_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_b3195_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_b3195_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_b3195_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_b3195_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_b3195_level0_col5" class="col_heading level0 col5" >Gateway</th>
#       <th id="T_b3195_level0_col6" class="col_heading level0 col6" >Subnet</th>
#       <th id="T_b3195_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_b3195_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b3195_row0_col0" class="data row0 col0" >b2093152-d754-4f55-8ade-2b251b944bd7</td>
#       <td id="T_b3195_row0_col1" class="data row0 col1" >link-sender</td>
#       <td id="T_b3195_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_b3195_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_b3195_row0_col4" class="data row0 col4" >DALL</td>
#       <td id="T_b3195_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_b3195_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_b3195_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_b3195_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_b3195_row1_col0" class="data row1 col0" >9af9a220-09f8-4c8b-8505-e39b3193129c</td>
#       <td id="T_b3195_row1_col1" class="data row1 col1" >link-receiver</td>
#       <td id="T_b3195_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_b3195_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_b3195_row1_col4" class="data row1 col4" >DALL</td>
#       <td id="T_b3195_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_b3195_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_b3195_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_b3195_row1_col8" class="data row1 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# Time to stable 1318 seconds
# Running post_boot_config ... Time to post boot config 1415 seconds
# <style type="text/css">
# #T_7f856 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_7f856 th {
#   text-align: left;
# }
# #T_7f856 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7f856 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_7f856 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7f856_row0_col0, #T_7f856_row0_col1, #T_7f856_row0_col2, #T_7f856_row0_col3, #T_7f856_row0_col4, #T_7f856_row0_col5, #T_7f856_row0_col6, #T_7f856_row0_col7, #T_7f856_row1_col0, #T_7f856_row1_col1, #T_7f856_row1_col2, #T_7f856_row1_col3, #T_7f856_row1_col4, #T_7f856_row1_col5, #T_7f856_row1_col6, #T_7f856_row1_col7, #T_7f856_row2_col0, #T_7f856_row2_col1, #T_7f856_row2_col2, #T_7f856_row2_col3, #T_7f856_row2_col4, #T_7f856_row2_col5, #T_7f856_row2_col6, #T_7f856_row2_col7, #T_7f856_row3_col0, #T_7f856_row3_col1, #T_7f856_row3_col2, #T_7f856_row3_col3, #T_7f856_row3_col4, #T_7f856_row3_col5, #T_7f856_row3_col6, #T_7f856_row3_col7, #T_7f856_row4_col0, #T_7f856_row4_col1, #T_7f856_row4_col2, #T_7f856_row4_col3, #T_7f856_row4_col4, #T_7f856_row4_col5, #T_7f856_row4_col6, #T_7f856_row4_col7, #T_7f856_row5_col0, #T_7f856_row5_col1, #T_7f856_row5_col2, #T_7f856_row5_col3, #T_7f856_row5_col4, #T_7f856_row5_col5, #T_7f856_row5_col6, #T_7f856_row5_col7, #T_7f856_row6_col0, #T_7f856_row6_col1, #T_7f856_row6_col2, #T_7f856_row6_col3, #T_7f856_row6_col4, #T_7f856_row6_col5, #T_7f856_row6_col6, #T_7f856_row6_col7, #T_7f856_row7_col0, #T_7f856_row7_col1, #T_7f856_row7_col2, #T_7f856_row7_col3, #T_7f856_row7_col4, #T_7f856_row7_col5, #T_7f856_row7_col6, #T_7f856_row7_col7, #T_7f856_row8_col0, #T_7f856_row8_col1, #T_7f856_row8_col2, #T_7f856_row8_col3, #T_7f856_row8_col4, #T_7f856_row8_col5, #T_7f856_row8_col6, #T_7f856_row8_col7, #T_7f856_row9_col0, #T_7f856_row9_col1, #T_7f856_row9_col2, #T_7f856_row9_col3, #T_7f856_row9_col4, #T_7f856_row9_col5, #T_7f856_row9_col6, #T_7f856_row9_col7, #T_7f856_row10_col0, #T_7f856_row10_col1, #T_7f856_row10_col2, #T_7f856_row10_col3, #T_7f856_row10_col4, #T_7f856_row10_col5, #T_7f856_row10_col6, #T_7f856_row10_col7, #T_7f856_row11_col0, #T_7f856_row11_col1, #T_7f856_row11_col2, #T_7f856_row11_col3, #T_7f856_row11_col4, #T_7f856_row11_col5, #T_7f856_row11_col6, #T_7f856_row11_col7, #T_7f856_row12_col0, #T_7f856_row12_col1, #T_7f856_row12_col2, #T_7f856_row12_col3, #T_7f856_row12_col4, #T_7f856_row12_col5, #T_7f856_row12_col6, #T_7f856_row12_col7, #T_7f856_row13_col0, #T_7f856_row13_col1, #T_7f856_row13_col2, #T_7f856_row13_col3, #T_7f856_row13_col4, #T_7f856_row13_col5, #T_7f856_row13_col6, #T_7f856_row13_col7, #T_7f856_row14_col0, #T_7f856_row14_col1, #T_7f856_row14_col2, #T_7f856_row14_col3, #T_7f856_row14_col4, #T_7f856_row14_col5, #T_7f856_row14_col6, #T_7f856_row14_col7, #T_7f856_row15_col0, #T_7f856_row15_col1, #T_7f856_row15_col2, #T_7f856_row15_col3, #T_7f856_row15_col4, #T_7f856_row15_col5, #T_7f856_row15_col6, #T_7f856_row15_col7, #T_7f856_row16_col0, #T_7f856_row16_col1, #T_7f856_row16_col2, #T_7f856_row16_col3, #T_7f856_row16_col4, #T_7f856_row16_col5, #T_7f856_row16_col6, #T_7f856_row16_col7, #T_7f856_row17_col0, #T_7f856_row17_col1, #T_7f856_row17_col2, #T_7f856_row17_col3, #T_7f856_row17_col4, #T_7f856_row17_col5, #T_7f856_row17_col6, #T_7f856_row17_col7, #T_7f856_row18_col0, #T_7f856_row18_col1, #T_7f856_row18_col2, #T_7f856_row18_col3, #T_7f856_row18_col4, #T_7f856_row18_col5, #T_7f856_row18_col6, #T_7f856_row18_col7, #T_7f856_row19_col0, #T_7f856_row19_col1, #T_7f856_row19_col2, #T_7f856_row19_col3, #T_7f856_row19_col4, #T_7f856_row19_col5, #T_7f856_row19_col6, #T_7f856_row19_col7, #T_7f856_row20_col0, #T_7f856_row20_col1, #T_7f856_row20_col2, #T_7f856_row20_col3, #T_7f856_row20_col4, #T_7f856_row20_col5, #T_7f856_row20_col6, #T_7f856_row20_col7, #T_7f856_row21_col0, #T_7f856_row21_col1, #T_7f856_row21_col2, #T_7f856_row21_col3, #T_7f856_row21_col4, #T_7f856_row21_col5, #T_7f856_row21_col6, #T_7f856_row21_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_7f856">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_7f856_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_7f856_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_7f856_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_7f856_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_7f856_level0_col4" class="col_heading level0 col4" >VLAN</th>
#       <th id="T_7f856_level0_col5" class="col_heading level0 col5" >MAC</th>
#       <th id="T_7f856_level0_col6" class="col_heading level0 col6" >Physical Device</th>
#       <th id="T_7f856_level0_col7" class="col_heading level0 col7" >Device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f856_row0_col0" class="data row0 col0" >router-link-p1</td>
#       <td id="T_7f856_row0_col1" class="data row0 col1" >router</td>
#       <td id="T_7f856_row0_col2" class="data row0 col2" >link-sender</td>
#       <td id="T_7f856_row0_col3" class="data row0 col3" >25</td>
#       <td id="T_7f856_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_7f856_row0_col5" class="data row0 col5" >B8:CE:F6:AF:85:56</td>
#       <td id="T_7f856_row0_col6" class="data row0 col6" >ens7np0</td>
#       <td id="T_7f856_row0_col7" class="data row0 col7" >ens7np0</td>
#     </tr>
#     <tr>
#       <td id="T_7f856_row1_col0" class="data row1 col0" >router-link-p2</td>
#       <td id="T_7f856_row1_col1" class="data row1 col1" >router</td>
#       <td id="T_7f856_row1_col2" class="data row1 col2" >link-receiver</td>
#       <td id="T_7f856_row1_col3" class="data row1 col3" >25</td>
#       <td id="T_7f856_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_7f856_row1_col5" class="data row1 col5" >B8:CE:F6:AF:85:57</td>
#       <td id="T_7f856_row1_col6" class="data row1 col6" >ens8np0</td>
#       <td id="T_7f856_row1_col7" class="data row1 col7" >ens8np0</td>
#     </tr>
#     <tr>
#       <td id="T_7f856_row2_col0" class="data row2 col0" >sender-0-link-sender-p1</td>
#       <td id="T_7f856_row2_col1" class="data row2 col1" >sender-0</td>
#       <td id="T_7f856_row2_col2" class="data row2 col2" >link-sender</td>
#       <td id="T_7f856_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_7f856_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_7f856_row2_col5" class="data row2 col5" >0A:81:94:8D:54:02</td>
#       <td id="T_7f856_row2_col6" class="data row2 col6" >ens7</td>
#       <td id="T_7f856_row2_col7" class="data row2 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_7f856_row3_col0" class="data row3 col0" >sender-1-link-sender-p1</td>
#       <td id="T_7f856_row3_col1" class="data row3 col1" >sender-1</td>
#       <td id="T_7f856_row3_col2" class="data row3 col2" >link-sender</td>
#       <td id="T_7f856_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_7f856_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_7f856_row3_col5" class="data row3 col5" >02:44:2D:C0:D1:D3</td>
#       <td id="T_7f856_row3_col6" class="data row3 col6" >ens7</td>
#       <td id="T_7f856_row3_col7" class="data row3 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_7f856_row4_col0" class="data row4 col0" >sender-2-link-sender-p1</td>
#       <td id="T_7f856_row4_col1" class="data row4 col1" >sender-2</td>
#       <td id="T_7f856_row4_col2" class="data row4 col2" >link-sender</td>
#       <td id="T_7f856_row4_col3" class="data row4 col3" >100</td>
#       <td id="T_7f856_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_7f856_row4_col5" class="data row4 col5" >02:76:DD:CA:86:30</td>
#       <td id="T_7f856_row4_col6" class="data row4 col6" >ens7</td>
#       <td id="T_7f856_row4_col7" class="data row4 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_7f856_row5_col0" class="data row5 col0" >sender-3-link-sender-p1</td>
#       <td id="T_7f856_row5_col1" class="data row5 col1" >sender-3</td>
#       <td id="T_
# Time to print interfaces 1482 seconds
# '1ebcf68b-84a8-4994-b09b-ca3d8320e0f7'

# %% [markdown]
# ## Configure resources

# %%
slice.get_state()
# Out:
# 'StableOK'

# %%
slice.wait_ssh(progress=True)
# Out:
# Waiting for slice . Slice state: StableOK
# Waiting for ssh in slice . ssh successful
# True

# %% [markdown]
# Bring up all of the network interfaces:

# %%
for iface in slice.get_interfaces():
    iface.ip_link_up()

# %% [markdown]
# Assign addresses to router interfaces and enable forwarding:

# %%
from ipaddress import ip_address, IPv4Address, IPv4Network

if_sender = slice.get_interface('router-link-p1')
if_sender.ip_addr_add(addr="10.10.1.1", subnet=IPv4Network("10.10.1.0/24"))
if_receive = slice.get_interface('router-link-p2')
if_receive.ip_addr_add(addr="10.10.2.1", subnet=IPv4Network("10.10.2.0/24"))

slice.get_node(name='router').execute("sudo sysctl -w net.ipv4.ip_forward=1")
# Out:
# net.ipv4.ip_forward = 1
# ('net.ipv4.ip_forward = 1\n', '')

# %% [markdown]
# Assign addresses to host (sender and receiver) interfaces and set up routes:

# %%
for i in range(n_endpoints):
    if_name = slice.get_interface('sender-' + str(i) + '-link-sender-p1')
    if_name.ip_addr_add(addr="10.10.1.1" + str(i) , subnet=IPv4Network("10.10.1.0/24"))
    slice.get_node(name='sender-' + str(i)).ip_route_add(subnet=IPv4Network("10.10.2.0/24"), gateway="10.10.1.1")
    
for i in range(n_endpoints):
    if_name = slice.get_interface('receiver-' + str(i) + '-link-receiver-p1')
    if_name.ip_addr_add(addr="10.10.2.1" + str(i) , subnet=IPv4Network("10.10.2.0/24"))
    slice.get_node(name='receiver-' + str(i)).ip_route_add(subnet=IPv4Network("10.10.1.0/24"), gateway="10.10.2.1")

# %% [markdown]
# Also install `iperf3` on sender and receiver hosts:

# %%
sender_nodes = [slice.get_node(name='sender-' + str(i))  for i in range(n_endpoints)]
receiver_nodes = [slice.get_node(name='receiver-' + str(i))  for i in range(n_endpoints)]

# %%
for n in sender_nodes:
    n.execute_thread("sudo apt update; sudo apt -y install iperf3")
for n in receiver_nodes:
    n.execute_thread("sudo apt update; sudo apt -y install iperf3")

# %%
# slice.delete()
